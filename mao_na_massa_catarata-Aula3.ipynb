# %% [markdown]
# # Mão na massa - Aula 1

# %%
url = '/content/drive/MyDrive/Alura/Cursos/3773 - TensorFlow Keras: Classificando imagens com redes convolucionais/Projeto/catarata'

# %%
import pathlib

# %%
data_dir=pathlib.Path(url)

# %%
import tensorflow as tf

# %%
batch_size = 64
altura = 416
largura = 416

# %%
treino = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset='training',
    seed=171,
    image_size=(altura,largura),
    batch_size=batch_size
)
# Out:
# Found 410 files belonging to 2 classes.
# Using 328 files for training.

# %%
validacao = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset='validation',
    seed=171,
    image_size=(altura,largura),
    batch_size=batch_size
)
# Out:
# Found 410 files belonging to 2 classes.
# Using 82 files for validation.

# %%
treino.class_names
# Out:
# ['immature', 'mature']

# %% [markdown]
# # Mão na massa - Aula 2

# %%
tf.random.set_seed(245)

# %%
modelo = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(416, 416, 3)),
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  #
])

# %%
# Compilando o modelo
modelo.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='binary_crossentropy',  # Use 'binary_crossentropy' porque o problema é binário
              metrics=['accuracy'])

# %%
epocas =10

history = modelo.fit(
    treino,
    validation_data=validacao,
    epochs=epocas
)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 6s 236ms/step - loss: 108.1400 - accuracy: 0.4970 - val_loss: 49.8241 - val_accuracy: 0.5854
# Epoch 2/10
# 6/6 [==============================] - 2s 167ms/step - loss: 25.8222 - accuracy: 0.6829 - val_loss: 17.8088 - val_accuracy: 0.7683
# Epoch 3/10
# 6/6 [==============================] - 2s 175ms/step - loss: 19.7340 - accuracy: 0.7866 - val_loss: 15.6739 - val_accuracy: 0.8659
# Epoch 4/10
# 6/6 [==============================] - 2s 165ms/step - loss: 12.8541 - accuracy: 0.8323 - val_loss: 38.7016 - val_accuracy: 0.7439
# Epoch 5/10
# 6/6 [==============================] - 3s 357ms/step - loss: 12.0210 - accuracy: 0.8598 - val_loss: 11.6005 - val_accuracy: 0.8171
# Epoch 6/10
# 6/6 [==============================] - 2s 207ms/step - loss: 7.0253 - accuracy: 0.8933 - val_loss: 9.9912 - val_accuracy: 0.8171
# Epoch 7/10
# 6/6 [==============================] - 2s 213ms/step - loss: 4.1398 - accuracy: 0.9390 - val_loss: 16.1455 - val_accuracy: 0.8659
# Epoch 8/10
# 6/6 [==============================] - 2s 169ms/step - loss: 2.4051 - accuracy: 0.9482 - val_loss: 6.7828 - val_accuracy: 0.8659
# Epoch 9/10
# 6/6 [==============================] - 2s 160ms/step - loss: 2.1031 - accuracy: 0.9421 - val_loss: 7.4569 - val_accuracy: 0.8659
# Epoch 10/10
# 6/6 [==============================] - 3s 238ms/step - loss: 1.7439 - accuracy: 0.9482 - val_loss: 10.7010 - val_accuracy: 0.8780

# %%
import matplotlib.pyplot as plt

# %%
def plota_resultados(history,epocas):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  intervalo_epocas = range(epocas)
  plt.figure(figsize=(12, 6))
  plt.subplot(1, 2, 1)
  plt.plot(intervalo_epocas, acc, label='Acurácia do Treino')
  plt.plot(intervalo_epocas, val_acc, label='Acurácia da Validação')
  plt.legend(loc='lower right')


  plt.subplot(1, 2, 2)
  plt.plot(intervalo_epocas, loss, label='Custo do Treino')
  plt.plot(intervalo_epocas, val_loss, label='Custo da Validação')
  plt.legend(loc='upper right')
  plt.show()

# %%
plota_resultados(history,epocas)

# %% [markdown]
# # Mão na massa - Aula 3

# %%
modelo = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(416, 416, 3)),
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
# Compilando o modelo
modelo.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='binary_crossentropy',  # Use 'binary_crossentropy' porque o problema é binário
              metrics=['accuracy'])

# %%
epocas =10

history = modelo.fit(
    treino,
    validation_data=validacao,
    epochs=epocas
)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 13s 778ms/step - loss: 13.8969 - accuracy: 0.5000 - val_loss: 5.1362 - val_accuracy: 0.5366
# Epoch 2/10
# 6/6 [==============================] - 3s 286ms/step - loss: 2.2229 - accuracy: 0.5366 - val_loss: 0.8227 - val_accuracy: 0.5122
# Epoch 3/10
# 6/6 [==============================] - 3s 285ms/step - loss: 0.5612 - accuracy: 0.7134 - val_loss: 0.5596 - val_accuracy: 0.7073
# Epoch 4/10
# 6/6 [==============================] - 3s 375ms/step - loss: 0.3489 - accuracy: 0.8628 - val_loss: 0.3706 - val_accuracy: 0.8902
# Epoch 5/10
# 6/6 [==============================] - 3s 292ms/step - loss: 0.2421 - accuracy: 0.9024 - val_loss: 0.3776 - val_accuracy: 0.8171
# Epoch 6/10
# 6/6 [==============================] - 3s 294ms/step - loss: 0.1303 - accuracy: 0.9634 - val_loss: 0.3063 - val_accuracy: 0.8537
# Epoch 7/10
# 6/6 [==============================] - 3s 290ms/step - loss: 0.0601 - accuracy: 0.9939 - val_loss: 0.3407 - val_accuracy: 0.8902
# Epoch 8/10
# 6/6 [==============================] - 4s 469ms/step - loss: 0.0627 - accuracy: 0.9817 - val_loss: 0.4468 - val_accuracy: 0.8780
# Epoch 9/10
# 6/6 [==============================] - 3s 292ms/step - loss: 0.0410 - accuracy: 0.9909 - val_loss: 0.2622 - val_accuracy: 0.9146
# Epoch 10/10
# 6/6 [==============================] - 3s 296ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9024

# %%
plota_resultados(history,epocas)

# %%
input_shape=(416, 416, 3)

# %%
modelo_base = tf.keras.applications.InceptionV3(input_shape=input_shape,include_top=False,weights='imagenet' )

# %%
modelo_base.trainable = False

# %%
modelo_base.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 416, 416, 3)]        0         []
#
#  conv2d_2 (Conv2D)           (None, 207, 207, 32)         864       ['input_3[0][0]']
#
#  batch_normalization (Batch  (None, 207, 207, 32)         96        ['conv2d_2[0][0]']
#  Normalization)
#
#  activation (Activation)     (None,
368    ['activation_90[0][0]']
#
#  average_pooling2d_8 (Avera  (None, 11, 11, 2048)         0         ['mixed9[0][0]']
#  gePooling2D)
#
#  conv2d_87 (Conv2D)          (None, 11, 11, 320)          655360    ['mixed9[0][0]']
#
#  batch_normalization_87 (Ba  (None, 11, 11, 384)          1152      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 11, 11, 384)          1152      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 11, 11, 384)          1152      ['conv2d_93[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 11, 11, 384)          1152      ['conv2d_94[0][0]']
#  tchNormalization)
#
#  conv2d_95 (Conv2D)          (None, 11, 11, 192)          393216    ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (Ba  (None, 11, 11, 320)          960       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 11, 11, 384)          0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 11, 11, 384)          0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 11, 11, 384)          0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  activation_92 (Activation)  (None, 11, 11, 384)          0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 11, 11, 192)          576       ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 11, 11, 320)          0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  mixed9_1 (Concatenate)      (None, 11, 11, 768)          0         ['activation_87[0][0]',
#                                                                      'activation_88[0][0]']
#
#  concatenate_1 (Concatenate  (None, 11, 11, 768)          0         ['activation_91[0][0]',
#  )                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)  (None, 11, 11, 192)          0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 11, 11, 2048)         0         ['activation_85[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21802784 (83.17 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
rescale = tf.keras.layers.Rescaling((1./255))
treino = treino.map(lambda x, y: (rescale(x), y))
validacao = validacao.map(lambda x, y: (rescale(x), y))

# %%
ultima_camada = modelo_base.get_layer('mixed7')
print('tamanho da última camada: ', ultima_camada.output_shape)
ultima_saida = ultima_camada.output
# Out:
# tamanho da última camada:  (None, 24, 24, 768)

# %%
x = tf.keras.layers.Flatten()(ultima_saida)

x = tf.keras.layers.Dense(1024, activation='relu')(x)

x = tf.keras.layers.Dropout(0.2)(x)

x = tf.keras.layers.Dense(4, activation=tf.nn.softmax)(x)

modelo = tf.keras.Model(inputs=modelo_base.input,outputs=x)

# %%
modelo.compile(optimizer = tf.keras.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
epocas =10

history = modelo.fit(
    treino,
    validation_data=validacao,
    epochs=epocas,

)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 30s 2s/step - loss: 42.3338 - accuracy: 0.4360 - val_loss: 19.9838 - val_accuracy: 0.5854
# Epoch 2/10
# 6/6 [==============================] - 5s 608ms/step - loss: 3.4315 - accuracy: 0.8598 - val_loss: 0.2315 - val_accuracy: 0.9634
# Epoch 3/10
# 6/6 [==============================] - 5s 685ms/step - loss: 0.3444 - accuracy: 0.9878 - val_loss: 7.1426 - val_accuracy: 0.8780
# Epoch 4/10
# 6/6 [==============================] - 5s 689ms/step - loss: 1.1605 - accuracy: 0.9543 - val_loss: 0.3673 - val_accuracy: 0.9878
# Epoch 5/10
# 6/6 [==============================] - 5s 687ms/step - loss: 0.0063 - accuracy: 0.9970 - val_loss: 0.1571 - val_accuracy: 0.9878
# Epoch 6/10
# 6/6 [==============================] - 5s 617ms/step - loss: 0.1436 - accuracy: 0.9817 - val_loss: 7.8065e-07 - val_accuracy: 1.0000
# Epoch 7/10
# 6/6 [==============================] - 5s 630ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9878
# Epoch 8/10
# 6/6 [==============================] - 5s 647ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3576 - val_accuracy: 0.9878
# Epoch 9/10
# 6/6 [==============================] - 6s 705ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6572 - val_accuracy: 0.9756
# Epoch 10/10
# 6/6 [==============================] - 5s 698ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.8712 - val_accuracy: 0.9756

# %%
plota_resultados(history,epocas)
